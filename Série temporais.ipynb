# %%
# Série temporais (Sazonalidade): Qualquer mudança ou padrão previsível.

# %%
# Importação de bibliotecas análiticas 
import pandas as pd 
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
# Buscando arquivo para análise
Dados = pd.read_csv ('C:\Cientista de dados\Modelos-Estatisticos\Dados de Emprego_IA.csv', encoding='ISO-8859-1', sep = ';')

# Visualização dos dados
Dados.head()
# Out:
#    Mês   Ano  Comercio  Alimento  Metalurgia
# 0  jan  2003       322        54          44
# 1  fev  2003       317        53          44
# 2  mar  2003       319        53          44
# 3  abr  2003       323        53          43
# 4  mai  2003       327        53          43

# %%
# Gráfico dos comercio por ano. 
plt.plot(Dados.Mês, Dados.Comercio)

# %%
result = Dados

# %%
fig, (ax1,ax2,ax3, ax4) = plt.subplots(4,1, figsize=(12,8))
Dados.observed.plot(ax=ax1)
# Dados.trend.plot(ax=ax2)
# Dados.seasonal.plot(ax=ax3)
# Dados.resid.plot(ax=ax4)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-0660bc93f282> in <module>
#       1 fig, (ax1,ax2,ax3, ax4) = plt.subplots(4,1, figsize=(12,8))
# ----> 2 Dados.observed.plot(ax=ax1)
#       3 # Dados.trend.plot(ax=ax2)
#       4 # Dados.seasonal.plot(ax=ax3)
#       5 # Dados.resid.plot(ax=ax4)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'observed'
